# %% [markdown]
# # Statistics Advanced-1 Assignment

# %% [markdown]
# ## Question 1
# **What is a random variable in probability theory?**
#
# **Answer:**
# A random variable is a variable that assigns a numerical value to each outcome of a random experiment.
#
# It represents outcomes in numeric form, making it easier to analyze mathematically.
#
# Example:
#
# Coin toss: Head → 1, Tail → 0
#
# Here, the number (0,1) is the random variable.

# %% [markdown]
# ## Question 2
# **What are the types of random variables**
#
# **Answer:**
# **Types of Random Variables:**
#
# There are **two main types**:
#
# 1. **Discrete Random Variable**
#
#    * Takes **countable values** (finite or countably infinite)
#    * Example: Number of heads in coin tosses
#
# 2. **Continuous Random Variable**
#
#    * Takes **any value within a range**
#    * Example: Height, weight, time

# %% [markdown]
# ## Question 3
# **Explain the difference between discrete and continuous distributions**
#
# **Answer:**
# ### **Difference Between Discrete and Continuous Distributions**
#
# **Discrete Distribution:**
#
# 1. The random variable takes **countable values**.
# 3. It uses **Probability Mass Function (PMF)**.
# 5. Examples include **Tossing of a coin** and **Rolling a dice**.
#
# **Continuous Distribution:**
#
# 1. The random variable takes **continuous values within a range**.
# 3. It uses **Probability Density Function (PDF)**.
# 5. Examples include **height, weight, and time**.

# %% [markdown]
# ## Question 4
# **What is a binomial distribution, and how is it used in probability?**
#
# **Answer:**
# **Binomial distribution** is a probability distribution that gives the probability of getting a fixed number of successes in a fixed number of independent trials, where each trial has two outcomes: success or failure.
#
# It is used to find the chance of a certain number of successes in repeated trials, such as heads in coin tosses or correct answers in a test.

# %% [markdown]
# ## Question 5
# **What is the standard normal distribution, and why is it important?**
#
# **Answer**:Standard Normal Distribution is a special type of normal distribution in which the mean (μ) is 0 and the standard deviation (σ) is 1.
#
# Importance:
# It is important because it helps us convert data into Z-scores, making it easy to compare values, find probabilities, and solve statistical problems.

# %% [markdown]
# ## Question 6
# **What is the Central Limit Theorem (CLT), and why is it critical in statistics?**
#
# **Answer**: Central Limit Theorem (CLT) states that the distribution of sample means becomes normal when the sample size is large (usually n ≥ 30), regardless of the population’s distribution.
#
# Importance:
# It is critical because it allows us to use normal distribution for probability calculations, hypothesis testing, and statistical inference in real-life data.

# %% [markdown]
# ## Question 7
# **What is the significance of confidence intervals in statistical analysis?**
#
# **Answer**:**Confidence intervals** show the **range of values** within which the **true population parameter** (like mean or proportion) is likely to lie.
#
# **Significance:**
# They help measure the **accuracy and reliability** of estimates and show how **confident** we are about the result instead of giving just a single value.

# %% [markdown]
# ## Question 8
# **What is the concept of expected value in a probability distribution?**
#
# **Answer**:
# Expected value is the average outcome we expect if an experiment is repeated many times.
#
# It tells the mean value of a random variable.
#
# It is a long-run average, not the result of one trial.

# %% [markdown]
# ## Question 9
# **Write a Python program to generate 1000 random numbers from a normal
# distribution with mean = 50 and standard deviation = 5. Compute its mean and standard
# deviation using NumPy, and draw a histogram to visualize the distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt

mean = 50
std = 5
n = 1000

data = np.random.normal(loc=mean, scale=std, size=n)

calculated_mean = np.mean(data)
calculated_std = np.std(data)

print(f"Mean of generated data: {calculated_mean:.2f}")
print(f"Standard Deviation of generated data: {calculated_std:.2f}")

plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title("Histogram of Normally Distributed Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean of generated data: 49.89
# Standard Deviation of generated data: 5.22

# %% [markdown]
# ##Question 10
# **You are working as a data analyst for a retail company. The company has
# collected daily sales data for 2 years and wants you to identify the overall sales trend.**
#
# daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
#  235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
#
# - Explain how you would apply the Central Limit Theorem to estimate the average sales with a 95% confidence interval.
# - Write the Python code to compute the mean sales and its confidence interval.
#
# **Answer**:
# Using the Central Limit Theorem, we can estimate the average daily sales and its 95% confidence interval because the sample mean will approximately follow a normal distribution.

# %%
import numpy as np

daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]

n = len(daily_sales)
mean_sales = np.mean(daily_sales)
std_sales = np.std(daily_sales, ddof=1)

z = 1.96  # 95% confidence
margin_error = z * (std_sales / np.sqrt(n))

ci_lower = mean_sales - margin_error
ci_upper = mean_sales + margin_error

print(f"Average Sales: {mean_sales:.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Average Sales: 248.25
# 95% Confidence Interval: (240.68, 255.82)
